# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hour.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
dataset = pd.read_csv('hour.csv')
del dataset['instant'] 
del dataset['dteday']
del dataset['casual']
del dataset['cnt'] 

print(dataset.info())
print(dataset.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 13 columns):
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# registered    17379 non-null int64
# dtypes: float64(4), int64(9)
# memory usage: 1.7 MB
# None
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# std        2.005771      0.465431      0.639357      0.192556      0.171850
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        1.000000      0.000000      1.000000      0.340000      0.333300
# 50%        3.000000      1.000000      1.000000      0.500000      0.484800
# 75%        5.000000      1.000000      2.000000      0.660000      0.621200
# max        6.000000      1.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed    registered
# count  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098    153.786869
# std        0.192930      0.122340    151.357286
# min        0.000000      0.000000      0.000000
# 25%        0.480000      0.104500     34.000000
# 50%        0.630000      0.194000    115.000000
# 75%        0.780000      0.253700    220.000000
# max        1.000000      0.850700    886.000000

# %%
for i, var in enumerate(('season', 'yr', 'mnth', 'hr', 'holiday', 'weekday','workingday',
                         'weathersit')):
    plt.figure(figsize=(10, 4))
    sns.boxplot(x = var , y ='registered', data = dataset)
    plt.show()

# %%
correlation = dataset.corr(method='spearman')
plt.figure(figsize=(10, 8))
#繪製熱力圖
sns.heatmap(correlation, linewidths=0.2, vmax=1, vmin=-1, linecolor='w',
            annot=True,annot_kws={'size':8},square=True)

# %%
del dataset['atemp']
dataset
# Out:
#        season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1   0     1   0        0        6           0           1  0.24
# 1           1   0     1   1        0        6           0           1  0.22
# 2           1   0     1   2        0        6           0           1  0.22
# 3           1   0     1   3        0        6           0           1  0.24
# 4           1   0     1   4        0        6           0           1  0.24
# 5           1   0     1   5        0        6           0           2  0.24
# 6           1   0     1   6        0        6           0           1  0.22
# 7           1   0     1   7        0        6           0           1  0.20
# 8           1   0     1   8        0        6           0           1  0.24
# 9           1   0     1   9        0        6           0           1  0.32
# 10          1   0     1  10        0        6           0           1  0.38
# 11          1   0     1  11        0        6           0           1  0.36
# 12          1   0     1  12        0        6           0           1  0.42
# 13          1   0     1  13        0        6           0           2  0.46
# 14          1   0     1  14        0        6           0           2  0.46
# 15          1   0     1  15        0        6           0           2  0.44
# 16          1   0     1  16        0        6           0           2  0.42
# 17          1   0     1  17        0        6           0           2  0.44
# 18          1   0     1  18        0        6           0           3  0.42
# 19          1   0     1  19        0        6           0           3  0.42
# 20          1   0     1  20        0        6           0           2  0.40
# 21          1   0     1  21        0        6           0           2  0.40
# 22          1   0     1  22        0        6           0           2  0.40
# 23          1   0     1  23        0        6           0           2  0.46
# 24          1   0     1   0        0        0           0           2  0.46
# 25          1   0     1   1        0        0           0           2  0.44
# 26          1   0     1   2        0        0           0           2  0.42
# 27          1   0     1   3        0        0           0           2  0.46
# 28          1   0     1   4        0        0           0           2  0.46
# 29          1   0     1   6        0        0           0           3  0.42
# ...       ...  ..   ...  ..      ...      ...         ...         ...   ...
# 17349       1   1    12  18        0        0           0           2  0.24
# 17350       1   1    12  19        0        0           0           1  0.34
# 17351       1   1    12  20        0        0           0           1  0.22
# 17352       1   1    12  21        0        0           0           1  0.20
# 17353       1   1    12  22        0        0           0           1  0.20
# 17354       1   1    12  23        0        0           0           1  0.20
# 17355       1   1    12   0        0        1           1           1  0.18
# 17356       1   1    12   1        0        1           1           1  0.18
# 17357       1   1    12   2        0        1           1           1  0.16
# 17358       1   1    12   3        0        1           1           1  0.16
# 17359       1   1    12   4        0        1           1           1  0.14
# 17360       1   1    12   5        0        1           1           1  0.16
# 17361       1   1    12   6        0        1           1           1  0.16
# 17362       1   1    12   7        0        1           1           1  0.16
# 17363       1   1    12   8        0        1           1           1  0.14
# 17364       1   1    12   9        0        1           1           2  0.18
# 17365       1   1    12  10        0        1           1           2  0.20
# 17366       1   1    12  11        0        1           1           2  0.22
# 17367       1   1    12  12        0        1           1           2  0.24
# 17368       1   1    12  13        0        1           1           2  0.26
# 17369       1   1    12  14        0        1           1           2  0.28
# 17370       1   1    12  15        0        1           1           2  0.28
# 17371       1   1    12  16        0        1           1           2  0.26
# 17372       1   1    12  17        0        1           1           2  0.26
# 17373       1   1    12  18        0        1           1           2  0.26
# 17374       1   1    12  19        0        1           1           2  0.26
# 17375       1   1    12  20        0        1           1           2  0.26
# 17376       1   1    12  21        0        1           1           1  0.26
# 17377       1   1    12  22        0        1           1           1  0.26
# 17378       1   1    12  23        0        1           1           1  0.26
#
#         hum  windspeed  registered
# 0      0.81     0.0000          13
# 1      0.80     0.0000          32
# 2      0.80     0.0000          27
# 3      0.75     0.0000          10
# 4      0.75     0.0000           1
# 5      0.75     0.0896           1
# 6      0.80     0.0000           0
# 7      0.86     0.0000           2
# 8      0.75     0.0000           7
# 9      0.76     0.0000           6
# 10     0.76     0.2537          24
# 11     0.81     0.2836          30
# 12     0.77     0.2836          55
# 13     0.72     0.2985          47
# 14     0.72     0.2836          71
# 15     0.77     0.2985          70
# 16     0.82     0.2985          52
# 17     0.82     0.2836          52
# 18     0.88     0.2537          26
# 19     0.88     0.2537          31
# 20     0.87     0.2537          25
# 21     0.87     0.1940          31
# 22     0.94     0.2239          17
# 23     0.88     0.2985          24
# 24     0.88     0.2985          13
# 25     0.94     0.2537          16
# 26     1.00     0.2836           8
# 27     0.94     0.1940           4
# 28     0.94     0.1940           1
# 29     0.77     0.2985           2
# ...     ...        ...         ...
# 17349  0.44     0.2985         113
# 17350  0.61     0.0000          86
# 17351  0.47     0.3284          63
# 17352  0.51     0.1642          42
# 17353  0.55     0.1940          30
# 17354  0.51     0.2239          39
# 17355  0.55     0.1940          30
# 17356  0.55     0.1940          13
# 17357  0.59     0.1642           8
# 17358  0.59     0.1045           1
# 17359  0.69     0.1045           3
# 17360  0.64     0.1940           9
# 17361  0.64     0.1642          40
# 17362  0.64     0.1343          83
# 17363  0.69     0.1343         187
# 17364  0.64     0.1045         144
# 17365  0.69     0.1343          87
# 17366  0.60     0.1940         114
# 17367  0.56     0.1940         172
# 17368  0.44     0.1642         165
# 17369  0.45     0.2239         185
# 17370  0.45     0.1343         246
# 17371  0.48     0.1940         184
# 17372  0.48     0.0896         150
# 17373  0.48     0.1343         112
# 17374  0.60     0.1642         108
# 17375  0.60     0.1642          81
# 17376  0.60     0.1642          83
# 17377  0.56     0.1343          48
# 17378  0.65     0.1343          37
#
# [17379 rows x 12 columns]

# %%
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn import metrics

# %%
x = dataset.iloc[:,:11]
y = dataset.iloc[:,11]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.5,random_state=555)
train = X_train.join(y_train)
test = X_test.join(y_test)

# %%
svm_rbf = svm.SVC(kernel='rbf', probability=True, gamma='auto', random_state=555)
model = svm_rbf.fit(X_train,y_train)
score = model.score(X_train,np.array(y_train))
print('traning_score=', score)
# Out:
# traning_score= 0.0910346415007

# %%
predict_y_test = model.predict(X_test)
accuracy = metrics.accuracy_score(predict_y_test, np.array(y_test))
precision = metrics.precision_score(predict_y_test, np.array(y_test), average='weighted')
recall = metrics.recall_score(predict_y_test, np.array(y_test), average='weighted')
print('traning_accuracy_score =', accuracy )
print('traning_precision_score =', precision )
print('traning_recall_score =', recall )
# Out:
# traning_accuracy_score = 0.0285385500575
# traning_precision_score = 0.0778628695501
# traning_recall_score = 0.0285385500575
# C:\Users\Jeff\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
predict_y = model.predict(X_train)

# %%
model.score(X_train, y_train)
# Out:
# 0.34148856873757694
