# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns   
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # <font color='red'>糖尿病的資料

# %% [markdown]
# # <font color='green'>ANS:

# %%
data = datasets.load_diabetes()

# %%
diabetes = pd.DataFrame(data["data"], columns=data["feature_names"])

# %%
diabetes["target"] = data["target"]

# %%
diabetes
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
sns.pairplot(diabetes)

# %%
sns.regplot(x="bmi", y="target", data=diabetes)

# %%
len(diabetes)sns.regplot(x="RM", y="target", data=boston)
# Out:
# 442

# %%
model = LinearRegression()  # 預設

# %%
model.fit(X=diabetes.iloc[:, 0:10].values, y=diabetes["target"].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predict_y = model.predict(X=diabetes.iloc[:, 0:10].values)

# %%
sns.regplot(x=predict_y, y=diabetes["target"].values, fit_reg=False) # 觀察否為斜直線

# %%
model.score(X=diabetes.iloc[:, 0:10].values, y=diabetes["target"].values)
# Out:
# 0.5177494254132934

# %%
model.coef_
# Out:
# array([ -10.01219782, -239.81908937,  519.83978679,  324.39042769,
#        -792.18416163,  476.74583782,  101.04457032,  177.06417623,
#         751.27932109,   67.62538639])

# %%
coefs = pd.DataFrame({"column": diabetes.columns[0:10], "coef": model.coef_})

# %%
coefs  # 觀察絕對值，越大越好，接近0的可以排除
# Out:
#   column        coef
# 0    age  -10.012198
# 1    sex -239.819089
# 2    bmi  519.839787
# 3     bp  324.390428
# 4     s1 -792.184162
# 5     s2  476.745838
# 6     s3  101.044570
# 7     s4  177.064176
# 8     s5  751.279321
# 9     s6   67.625386

# %%
model.fit(X=diabetes.iloc[:, [2, 4, 8]].values, y=diabetes["target"].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.score(X=diabetes.iloc[:, [2, 4, 8]].values, y=diabetes["target"].values)
# Out:
# 0.47002448720669265
